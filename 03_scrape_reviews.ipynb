# %% [markdown]
# # Extract Restaurant Review
# Notebook used to extract the TripAdvisor Restaurant Review data

# %% [markdown]
# ## 1. Basic Setup

# %% [markdown]
# ### 1.1 Loading of Libaries

# %%
from selenium import webdriver      # conda install -c conda-forge selenium
from time import sleep
from selenium.webdriver.chrome.options import Options

import pandas as pd
import numpy as np
import re

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Read in Dataset with Restaurant Informtaion
# - To generate the "Review Pages" to scrape

# %%
df_restaurant = pd.read_csv("data/full_restaurant_rating_data.csv")
df_restaurant_subset = df_restaurant[["url", "num_of_reviews"]].copy()

# %%
df_restaurant_subset
# Out:
#                                                      url  num_of_reviews
# 0      https://www.tripadvisor.com.sg/Restaurant_Revi...              16
# 1      https://www.tripadvisor.com.sg/Restaurant_Revi...            1488
# 2      https://www.tripadvisor.com.sg/Restaurant_Revi...            1420
# 3      https://www.tripadvisor.com.sg/Restaurant_Revi...             249
# 4      https://www.tripadvisor.com.sg/Restaurant_Revi...             626
# ...                                                  ...             ...
# 11156  https://www.tripadvisor.com.sg/Restaurant_Revi...               0
# 11157  https://www.tripadvisor.com.sg/Restaurant_Revi...               0
# 11158  https://www.tripadvisor.com.sg/Restaurant_Revi...               0
# 11159  https://www.tripadvisor.com.sg/Restaurant_Revi...               0
# 11160  https://www.tripadvisor.com.sg/Restaurant_Revi...               0
#
# [11161 rows x 2 columns]

# %%
# Functions that generate the list of "review pages" of a restaurant (given its restaurant url page on TripAdvisor)

def get_list_of_reviews_url(url, num_of_reviews):
    lst_of_urls = [url]
    url_front = re.findall(".*\-Reviews", url)[0]
    url_back = re.findall("(?<=Reviews\-).*",  url)[0]

    max_review_page = int(np.ceil(num_of_reviews/ 10) * 10)
    for i in range(10, max_review_page, 10):
        new_url = url_front + f"-or{i}-" + url_back
        lst_of_urls.append(new_url)

    return lst_of_urls

# %%
# variable to control which range of index to scrape from df_restaurant
index_start = 2000;
index_end = 2003;

driver = webdriver.Chrome()

dct_review_links = {}   # key: restaurant url, value: list of review pages url

# %%
for idx, row in df_restaurant.loc[index_start:index_end,:].iterrows():
        list_of_urls = get_list_of_reviews_url(row["url"], row["num_of_reviews"])
        counter = len(list_of_urls)
        for i in range(len(list_of_urls)-1, -1, -1):
            driver.get(list_of_urls[i])
            curr_url = driver.current_url
            if curr_url == list_of_urls[0]:
                counter = counter - 1
            else:
                break
        dct_review_links[idx] = [row["url"]]
        print(f"Done {idx} of {index_end}")
# Out:
# Done 2000 of 2003
# Done 2001 of 2003
# Done 2002 of 2003
# Done 2003 of 2003

# %%
df_links = pd.DataFrame()

for key, values in dct_review_links.items():
    df_links = df_links.append(pd.DataFrame({"restaurant_url":[df_restaurant.loc[key, "url"]] * len(values), "review_url": values}))

df_links.reset_index(drop=True, inplace=True)

# %%
df_links
# Out:
#                                       restaurant_url  \
# 0  https://www.tripadvisor.com.sg/Restaurant_Revi...
# 1  https://www.tripadvisor.com.sg/Restaurant_Revi...
# 2  https://www.tripadvisor.com.sg/Restaurant_Revi...
# 3  https://www.tripadvisor.com.sg/Restaurant_Revi...
#
#                                           review_url
# 0  https://www.tripadvisor.com.sg/Restaurant_Revi...
# 1  https://www.tripadvisor.com.sg/Restaurant_Revi...
# 2  https://www.tripadvisor.com.sg/Restaurant_Revi...
# 3  https://www.tripadvisor.com.sg/Restaurant_Revi...

# %% [markdown]
# ## 3. Scraping of Restaurant Reviews

# %%
# Function to scrape review information from a page
def scrape_page_review(df, restaurant_url):
    review_container = driver.find_elements_by_class_name("review-container")
    date_of_visit_list = [e.find_element_by_class_name("prw_reviews_stay_date_hsx").text for e in review_container]
    for i in range(0, len(review_container)):
        # ----------------------------- Review Title ----------------------------- #
        review_title = review_container[i].find_element_by_class_name("quote").text

        # ----------------------------- Review Date ----------------------------- #
        review_date = review_container[i].find_element_by_class_name("ratingDate").get_attribute("title")

        # ----------------------------- Review Rating (out of 5) ----------------------------- #
        try:
            review_rating = review_container[i].find_element_by_class_name("ui_bubble_rating").get_attribute("class")
        except:
            return df

        # ----------------------------- Review Description ----------------------------- #
        review_description = review_container[i].find_element_by_class_name("partial_entry").get_attribute("textContent").replace("...More", " ")
        # ----------------------------- More Review Description ----------------------------- #
        try:
            more_description = driver.find_elements_by_class_name("review-container")[i].find_element_by_class_name("postSnippet").get_attribute("innerHTML")
            review_description = review_description.replace + more_description
        except:
            pass
        
        try:
            driver.find_elements_by_class_name("review-container")[i].find_element_by_class_name("ulBlueLinks").click()
        except:
            pass

        # ----------------------------- Date of visit to restaurant ----------------------------- #
        review_date_of_visit = date_of_visit_list[i]
        
        # ----------------------------- Image uploaded ----------------------------- #
        try:
            review_img_src = [element.find_element_by_tag_name("img").get_attribute("src") 
                for element in review_container[i].find_elements_by_class_name("imgWrap")]
        except:
            review_img_src = []

        df_temp = pd.DataFrame({
            "rating": [review_rating],
            "date": [review_date],
            "title": [review_title],
            "description": [review_description],
            "date_of_visit": [review_date_of_visit],
            "img_src": [review_img_src],
            "url": [restaurant_url]
        })

        df = df.append(df_temp)

    return df

# %%
# to store scraped dataset
df_scraped = pd.DataFrame()

# %%
# index of df_links to begin scrape
start = 0

# number of times to run the codes below
loop = 2

# %%
for i in range(1,loop):
    driver = webdriver.Chrome()
    driver.maximize_window()

    index_start = start + ((i-1) * 10)
    index_end = start + (i*10) - 1
    
    df_scraped = pd.DataFrame()
    for idx, row in df_links.loc[index_start:index_end,:].iterrows():
        driver.get(row["review_url"])
        sleep(10)        # shorter sleep time faster but easier to break from StaleElementReferenceException
        attempts = 0
        done = False
        while (attempts < 5) and (not done):
            try:
                df_scraped = scrape_page_review(df_scraped, row["restaurant_url"])
                print(f"Done {idx} of {index_end}")
                done = True
            except:
                attempts += 1
            
    # scraped file goes into review directory
    df_scraped.to_csv(f"review/reviews_from_{index_start}_to_{idx}.csv", encoding="utf-8-sig", index=False)
    driver.quit()
# Out:
# Done 0 of 9
# Done 1 of 9
# Done 2 of 9
# Done 3 of 9

# %%
df_scraped.reset_index(drop=True, inplace=True)
df_scraped
# Out:
#                         rating               date  \
# 0   ui_bubble_rating bubble_50   16 February 2022
# 1   ui_bubble_rating bubble_50    15 January 2022
# 2   ui_bubble_rating bubble_50  23 September 2021
# 3   ui_bubble_rating bubble_30   20 December 2020
# 4   ui_bubble_rating bubble_40    3 November 2020
# 5   ui_bubble_rating bubble_10    30 October 2020
# 6   ui_bubble_rating bubble_10     22 August 2020
# 7   ui_bubble_rating bubble_50       24 June 2020
# 8   ui_bubble_rating bubble_50   20 February 2020
# 9   ui_bubble_rating bubble_50    2 December 2019
# 10  ui_bubble_rating bubble_40    16 October 2018
# 11  ui_bubble_rating bubble_40   4 September 2018
# 12  ui_bubble_rating bubble_40        8 June 2018
# 13  ui_bubble_rating bubble_50      27 March 2018
# 14  ui_bubble_rating bubble_40   12 December 2017
# 15  ui_bubble_rating bubble_50     3 October 2017
# 16  ui_bubble_rating bubble_40  11 September 2017
# 17  ui_bubble_rating bubble_50     26 August 2017
# 18  ui_bubble_rating bubble_50     20 August 2017
# 19  ui_bubble_rating bubble_40        2 June 2017
# 20  ui_bubble_rating bubble_50   7 September 2021
# 21  ui_bubble_rating bubble_50       25 June 2021
# 22  ui_bubble_rating bubble_10    4 November 2020
# 23  ui_bubble_rating bubble_40        23 May 2020
# 24  ui_bubble_rating bubble_20       6 April 2020
# 25  ui_bubble_rating bubble_10      13 March 2020
# 26  ui_bubble_rating bubble_50       9 March 2020
# 27  ui_bubble_rating bubble_50       9 March 2020
# 28  ui_bubble_rating bubble_50   12 February 2020
# 29  ui_bubble_rating bubble_50    9 February 2020
# 30  ui_bubble_rating bubble_40         4 May 2021
# 31  ui_bubble_rating bubble_40   19 December 2020
# 32  ui_bubble_rating bubble_40    27 October 2020
# 33  ui_bubble_rating bubble_20    16 October 2020
# 34  ui_bubble_rating bubble_40     6 January 2020
# 35  ui_bubble_rating bubble_40   12 November 2019
# 36  ui_bubble_rating bubble_40   4 September 2019
# 37  ui_bubble_rating bubble_40     3 October 2018
# 38  ui_bubble_rating bubble_50      5 August 2018
# 39  ui_bubble_rating bubble_40       9 April 2018
#
#                                                 title  \
# 0                Best tempura experience in Singapore
# 1                           Best tempura in Singapore
# 2                                     Repeat customer
# 3                                Room for improvement
# 4                                    Tempura overload
# 5                                        rubbish food
# 6                                           Bad value
# 7                          We had the tsubaki set and
# 8             Fantastic tempura by the master himself
# 9                       Great food, attentive service
# 10                          Very good value-for-money
# 11                                          Good food
# 12                              great healthy options
# 13                   Convenient for coffee and drinks
# 14                               Fantastic breakfasts
# 15               Excellent breakfasts available here.
# 16                                       A quick bite
# 17             very good food and even better service
# 18           Great place for a coffee and small bites
# 19                        Excellent Service by Sandun
# 20                               Excellent Experience
# 21                                  Steaks 🥩 & Wine 🍷
# 22                         Most of items unavailable.
# 23                       Restaurant, Bar and Butchery
# 24                                      Poor service.
# 25                              First and last visit.
# 26                Great quality food & nice ambiance!
# 27                                      Awesome Steak
# 28                   There are a few must eats/drinks
# 29                            Try the Beef Ragu Pasta
# 30                                       Dessert Time
# 31                                       Tasty sweets
# 32                         the famous ah chew dessert
# 33                                     Below standard
# 34                                        Always good
# 35                         A Place For Local Desserts
# 36                              Lots of the varieties
# 37                                 Good Dessert Place
# 38                        All time favourite desserts
# 39  old-fashioned Hongkong-style cafe with delicio...
#
#                                           description  \
# 0   Awesome place to enjoy other type of Japanese ...
# 1   The batter is thin and crispy, so we can enjoy...
# 2   Chloe's service is nothing short of excellent,...
# 3   Had a nice counter seat. Ordered SGD 85 set of...
# 4   My hubby and I went there for dinner one Sat n...
# 5   honestly might get a sore throat--tempura over...
# 6   We didn't get to sit at the counter and the ou...
# 7   We had the tsubaki set and the chef was Execut...
# 8   We were invited to lunch here today by some fr...
# 9   Had the set menu. Sit down dinner with friends...
# 10  This unassuming, and cozy (read "small") resta...
# 11  Just good to be able to get good food without ...
# 12  loved the smoothies, fruit juices and very hea...
# 13  In the hotel lobby for quick and easy service ...
# 14  Great choice for breakfast - all the usual stu...
# 15  Had breakfast here on most days It gets very b...
# 16  This is a good spot for a quick bite while wai...
# 17  Lunched here on a busy Saturday afternoon. Ser...
# 18  Have been coming to this place 2 weeks in a ro...
# 19  Excellent take away outlet.\n\nService is quic...
# 20  Not to say the food is excellent (especially t...
# 21  Came here on a Friday evening! We had a great ...
# 22  Unfortunately, i agree with other diners that ...
# 23  Celebrated my last night in Singapore by havin...
# 24  Seriously and very strongly suggest you spend ...
# 25  Waited almost an hour for my food to arrive. R...
# 26  First visit to Cavemen Restaurant ~ great plac...
# 27  The steak is cooked perfectly and the dessert ...
