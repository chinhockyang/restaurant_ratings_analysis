# %%
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Loading Data

# %%
data = pd.read_csv("data/final_restaurant_rating_data.csv")

# %%
list(data.columns)
# Out:
# ['overall_rating',
#  'average_rating',
#  'average_rating_category',
#  'is_travellors_choice',
#  'is_michellin',
#  'is_in_mall',
#  'walking_distance',
#  'region_bedok',
#  'region_bishan_toa_payoh',
#  'region_bugis_city_hall',
#  'region_bukit_merah_southern_islands',
#  'region_bukit_timah',
#  'region_changi',
#  'region_downtown',
#  'region_geylang',
#  'region_kallang',
#  'region_marina_bay',
#  'region_marina_centre',
#  'region_newton_orchard',
#  'region_north_region',
#  'region_northeast_region',
#  'region_novena',
#  'region_outram',
#  'region_paya_lebar_tampines_pasir_ris',
#  'region_queenstown',
#  'region_rochor',
#  'region_singapore_river',
#  'region_tanglin',
#  'region_west_region',
#  'has_price_category',
#  'price_category',
#  'above_median_dist_from_nearby_attraction',
#  'nearby_attraction_arab_street',
#  'nearby_attraction_boat_quay',
#  'nearby_attraction_chinatown',
#  'nearby_attraction_east_coast_park',
#  'nearby_attraction_garden',
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Meals Visualization

# %%
plt.pie(data.meal_lunch.value_counts(),labels=["Lunch not available","Lunch available"])
# Out:
# ([<matplotlib.patches.Wedge at 0x22516919048>,
# ...
#  [Text(-0.3766235446174412, 1.0335157016900103, 'Lunch not available'),
#   Text(0.3766236413821629, -1.0335156664279648, 'Lunch available')])

# %%
plt.pie(data.meal_dinner.value_counts(),labels=["Dinner not available","Dinner available"])
# Out:
# ([<matplotlib.patches.Wedge at 0x22516966cc8>,
# ...
#  [Text(-0.48788168279000355, 0.9858861311520689, 'Dinner not available'),
#   Text(0.4878815904846805, -0.9858861768308442, 'Dinner available')])

# %%
plt.pie(data.meal_drinks.value_counts(),labels=["Drinks not available","Drinks available"])
# Out:
# ([<matplotlib.patches.Wedge at 0x225169bbb88>,
# ...
#  [Text(-1.0188228016840293, 0.41472894614278527, 'Drinks not available'),
#   Text(1.0188228308063214, -0.4147288746009784, 'Drinks available')])

# %%
plt.pie(data.meal_breakfast.value_counts(),labels=["Breakfast not available","Breakfast available"])
# Out:
# ([<matplotlib.patches.Wedge at 0x22516a12b88>,
# ...
#  [Text(-1.0171844723224348, 0.41873111810101993, 'Breakfast not available'),
#   Text(1.0171844919246518, -0.41873107048317787, 'Breakfast available')])

# %%
plt.pie(data.meal_brunch.value_counts(),labels=["Brunch not available","Brunch available"])
# Out:
# ([<matplotlib.patches.Wedge at 0x22516a66bc8>,
# ...
#  [Text(-0.9983329407615702, 0.4618780568400662, 'Brunch not available'),
#   Text(0.9983329191394967, -0.4618781035754037, 'Brunch available')])

# %%
plt.pie(data["meal_after_hours"].value_counts(),labels=["After-hours not available","After-hours available"])
# Out:
# ([<matplotlib.patches.Wedge at 0x22516abb848>,
# ...
#  [Text(-1.0667858270681738, 0.26826852064018375, 'After-hours not available'),
#   Text(1.0667858333474511, -0.2682684956702597, 'After-hours available')])

# %% [markdown]
# ## Establishment Type

# %%
#data.establishment_type.value_counts().plot(kind="bar")

# %% [markdown]
# ## Cuisines

# %%
data[[ 'cuisine_arabic',
 'cuisine_asian',
 'cuisine_chinese',
 'cuisine_european',
 'cuisine_indian',
 'cuisine_international',
 'cuisine_italian',
 'cuisine_japanese',
 'has_cuisines',
 'cuisine_north_american',
 'cuisine_others',
 'cuisine_sea',
 'cuisine_south_american',]].sum().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Features

# %%
data['feature_delivery'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='feature_delivery'>

# %%
data["feature_reservations"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='feature_reservations'>

# %%
data['feature_outdoor_seating'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='feature_outdoor_seating'>

# %%
data.feature_seating.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='feature_seating'>

# %%
data['feature_highchairs_available'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='feature_highchairs_available'>

# %%
data['feature_digital_payments'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='feature_digital_payments'>

# %%
data['feature_free_wifi'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='feature_free_wifi'>

# %%
data['feature_cash_only'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='feature_cash_only'>

# %%
data['feature_wheelchair_accessible'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='feature_wheelchair_accessible'>

# %%
data['feature_table_service'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='feature_table_service'>

# %%
data['feature_live_music'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='feature_live_music'>

# %%
data['has_features'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='has_features'>

# %%
data.feature_parking_avail.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='feature_parking_avail'>

# %%
data.feature_alcohol_avail.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='feature_alcohol_avail'>

# %%
data.feature_creditcard_avail.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='feature_creditcard_avail'>

# %% [markdown]
# ## Diets

# %%
data['diet_vegetarian_friendly'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='diet_vegetarian_friendly'>

# %%
data[ 'diet_vegan_options'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='diet_vegan_options'>

# %%
data['diet_gluten_free_options'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='diet_gluten_free_options'>

# %%
data.diet_halal.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='diet_halal'>
